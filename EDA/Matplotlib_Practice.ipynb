# %% [markdown]
# <a href="https://colab.research.google.com/github/ChitraChaudhari/GC_DataEngineering_Bootcamp/blob/main/EDA/Matplotlib_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=[1,2,3,4,5,6,7]
y=[50,53,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='green',linewidth=3,marker='o')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather Data')
plt.plot(x,y,color='green',linewidth=3,marker='o')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather Data')
plt.plot(x,y,'--g+')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather Data')
plt.plot(x,y,'rD')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather Data')

plt.plot(x,y,'-rD', alpha=0.4,markersize = 7)

# %%
days = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather Data')

plt.plot(days,max_t,label = 'max')
plt.plot(days,min_t,label = 'min')
plt.plot(days,avg_t,label = 'avg')

plt.legend(loc='best',shadow=True, fontsize = 'large')

plt.grid()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
plt.title("US Tech Stock")
plt.xlabel("Company")
plt.ylabel("Revenue")

plt.bar(company,revenue,label='Revenue')
plt.legend()

# %%
import numpy as np

xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
profit = [40,2,34,12]

# %%
plt.xticks(xpos,company)
plt.ylabel("Revenue")

plt.bar(xpos,revenue,label='Revenue')
plt.bar(xpos,profit,label='Revenue')
plt.legend()

# %%
plt.xticks(xpos,company)
plt.ylabel("Revenue")

plt.bar(xpos-0.2,revenue,width=0.4,label='Revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='Revenue')
plt.legend()

# %%
plt.yticks(xpos,company)
plt.title("US Tech stocks")

plt.barh(xpos,revenue,label='Revenue')
plt.barh(xpos,profit,label='Revenue')
plt.legend()

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar) # by default number of bins is set to 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <a list of 10 Patch objects>)

# %%
# but we want "80-100",'100-125','above 125'
plt.hist(blood_sugar, bins = 3)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <a list of 3 Patch objects>)

# %%
plt.hist(blood_sugar, bins = 3, rwidth = 0.95)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <a list of 3 Patch objects>)

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth = 0.95,color='g')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth = 0.95,color='g',histtype='step')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 1 Patch objects>)

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

# %%
plt.xlabel("Sugar range")
plt.ylabel("Total no of patients")
plt.title("Blood sugar analyasis")

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth = 0.95,label=['men','women'])
plt.legend()

# %%
plt.ylabel("Sugar range")
plt.xlabel("Total no of patients")
plt.title("Blood sugar analyasis")

plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth = 0.95,label=['men','women'], orientation='horizontal')
plt.legend()

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
plt.pie(exp_vals, labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f08abb03290>,
#   <matplotlib.patches.Wedge at 0x7f08abb03590>,
#   <matplotlib.patches.Wedge at 0x7f08abb03650>,
#   <matplotlib.patches.Wedge at 0x7f08abb0b250>,
#   <matplotlib.patches.Wedge at 0x7f08abb0b510>],
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Phone/Internet Bill'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car '),
#   Text(1.0615045230766318, -0.28845822485734873, 'Other Utilities')])

# %%
plt.pie(exp_vals, labels=exp_labels,radius=2, autopct="%0.2f%%",explode=[0,0.1,0,0,0],startangle=180)
plt.show()

# %%
plt.savefig("ExpenceChaart.pdf",bbox_inches='tight')
