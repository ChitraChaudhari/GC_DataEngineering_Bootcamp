# %% [markdown]
# <a href="https://colab.research.google.com/github/ChitraChaudhari/GC_DataEngineering_Bootcamp/blob/main/EDA/Pandas_Dataframe_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DataFrames**
#
# - a complex datastructure which uses several Series
# objects underneath it.
# - used to represent table data.
# - Similar to a table, DataFrames have columns, column names, and rows with row indexes.

# %%
import pandas as pd
df = pd.DataFrame({
                'marks': [70, 66, 100, 88], 'age': [29, 32, 31, 28], \
                'sex': ['F', 'M', 'F', 'F'], 'name':['Jane', 'John', \
                'Sally', 'Sandy'], 'ssn':['1234', '3456', '4567', '5678']
                })
print(df)
# Out:
#    marks  age sex   name   ssn
# 0     70   29   F   Jane  1234
# 1     66   32   M   John  3456
# 2    100   31   F  Sally  4567
# 3     88   28   F  Sandy  5678

# %%
data = {'color' : ['blue','green','yellow','red','white'],
        'object': ['ball','pen','pencil','paper','mug'],
        'price':[1.2,1.0,0.6,0.9,1.7]}

data
# Out:
# {'color': ['blue', 'green', 'yellow', 'red', 'white'],
#  'object': ['ball', 'pen', 'pencil', 'paper', 'mug'],
#  'price': [1.2, 1.0, 0.6, 0.9, 1.7]}

# %%
frame = pd.DataFrame(data)
frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7

# %%
type(frame)
# Out:
# pandas.core.frame.DataFrame

# %%
frame2 = pd.DataFrame(data, columns=['object','price'])
frame2
# Out:
#    object  price
# 0    ball    1.2
# 1     pen    1.0
# 2  pencil    0.6
# 3   paper    0.9
# 4     mug    1.7

# %%
frame3 = pd.DataFrame(data, index=['one','two','three','four','five'])
frame3
# Out:
#         color  object  price
# one      blue    ball    1.2
# two     green     pen    1.0
# three  yellow  pencil    0.6
# four      red   paper    0.9
# five    white     mug    1.7

# %% [markdown]
# . Instead of using a dict object, you can define within the constructor
# three arguments, in the following order: **a data matrix**, then an array containing the labels assigned to the
# **index** option, and finally an array containing the names of the **columns** assigned to the columns option.

# %%
import numpy as np

frame4 = pd.DataFrame(np.arange(16).reshape((4,4)),
                      index = ['red','blue','yellow','white'],
                      columns= ['ball','pen','pencil','paper'])

frame4
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    1.0
# 2  yellow  pencil    0.6
# 3     red   paper    0.9
# 4   white     mug    1.7

# %%
# if we want to know the name of all the columns of a DataFrame
frame.columns
# Out:
# Index(['color', 'object', 'price'], dtype='object')

# %%
#  to get the list of indexes
frame.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# you can get the entire set of data using the values attribute.
frame.values
# Out:
# array([['blue', 'ball', 1.2],
#        ['green', 'pen', 1.0],
#        ['yellow', 'pencil', 0.6],
#        ['red', 'paper', 0.9],
#        ['white', 'mug', 1.7]], dtype=object)

# %%
frame['price']
# Out:
# 0    1.2
# 1    1.0
# 2    0.6
# 3    0.9
# 4    1.7
# Name: price, dtype: float64

# %%
frame.price
# Out:
# 0    1.2
# 1    1.0
# 2    0.6
# 3    0.9
# 4    1.7
# Name: price, dtype: float64

# %%
frame[0:1]
# Out:
#   color object  price
# 0  blue   ball    1.2

# %%
frame[1:3]
# Out:
#     color  object  price
# 1   green     pen    1.0
# 2  yellow  pencil    0.6

# %%
frame['object'][1]
# Out:
# 'pen'

# %%
mixrow = frame[0:1]
mixrow
# Out:
#   color object  price
# 0  blue   ball    1.2

# %%
type(mixrow)
# Out:
# pandas.core.frame.DataFrame

# %%
frame.index.name = 'id'
frame.columns.name = 'item'
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    1.0
# 2     yellow  pencil    0.6
# 3        red   paper    0.9
# 4      white     mug    1.7

# %%
# add new column
frame['new'] =12
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2   12
# 1      green     pen    1.0   12
# 2     yellow  pencil    0.6   12
# 3        red   paper    0.9   12
# 4      white     mug    1.7   12

# %%
frame['new'] = [3.0,1.3,2.2,0.8,1.1]
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2  3.0
# 1      green     pen    1.0  1.3
# 2     yellow  pencil    0.6  2.2
# 3        red   paper    0.9  0.8
# 4      white     mug    1.7  1.1

# %%
ser = pd.Series(np.arange(5))
ser
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
frame['new'] =ser
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2    0
# 1      green     pen    1.0    1
# 2     yellow  pencil    0.6    2
# 3        red   paper    0.9    3
# 4      white     mug    1.7    4

# %%
frame.nlargest(3,'price')
# Out:
# item  color object  price  new
# id
# 4     white    mug    1.7    4
# 0      blue   ball    1.2    0
# 1     green    pen    1.0    1

# %%
frame.nlargest(3,['price','new'])
# Out:
# item  color object  price  new
# id
# 4     white    mug    1.7    4
# 0      blue   ball    1.2    0
# 1     green    pen    1.0    1

# %%
frame.nlargest(3,['new','price'])
# Out:
# item   color  object  price  new
# id
# 4      white     mug    1.7    4
# 3        red   paper    0.9    3
# 2     yellow  pencil    0.6    2

# %%
df = pd.DataFrame({
                'marks': [70, 66, 100, 88], 'age': [29, 32, 31, 28], \
                'sex': ['F', 'M', 'F', 'F'], 'name':['Jane', 'John', \
                'Sally', 'Sandy'], 'ssn':['1234', '3456', '4567', '5678']
                })
print(df)
# Out:
#    marks  age sex   name   ssn
# 0     70   29   F   Jane  1234
# 1     66   32   M   John  3456
# 2    100   31   F  Sally  4567
# 3     88   28   F  Sandy  5678

# %%
df.set_index('ssn',inplace=True)
df
# Out:
#       marks  age sex   name
# ssn
# 1234     70   29   F   Jane
# 3456     66   32   M   John
# 4567    100   31   F  Sally
# 5678     88   28   F  Sandy

# %%
df = pd.DataFrame({
                'marks': [70, 66, 100, 88], 'age': [29, 32, 31, 28], \
                'sex': ['F', 'M', 'F', 'F'], 'name':['Jane', 'John', \
                'Sally', 'Sandy'], 'ssn':['1234', '3456', '4567', '5678']
                })
print(df)
# Out:
#    marks  age sex   name   ssn
# 0     70   29   F   Jane  1234
# 1     66   32   M   John  3456
# 2    100   31   F  Sally  4567
# 3     88   28   F  Sandy  5678

# %%
df.index = df['ssn']
df
# Out:
#       marks  age sex   name   ssn
# ssn
# 1234     70   29   F   Jane  1234
# 3456     66   32   M   John  3456
# 4567    100   31   F  Sally  4567
# 5678     88   28   F  Sandy  5678

# %%
df.drop('ssn',axis =1, inplace = True)
df
# Out:
#       marks  age sex   name
# ssn
# 1234     70   29   F   Jane
# 3456     66   32   M   John
# 4567    100   31   F  Sally
# 5678     88   28   F  Sandy

# %%
df.sort_values(by=['marks'],inplace=True)
df
# Out:
#       marks  age sex   name
# ssn
# 3456     66   32   M   John
# 1234     70   29   F   Jane
# 5678     88   28   F  Sandy
# 4567    100   31   F  Sally

# %%
df.sort_values(by=['age','marks'],inplace=True)
df
# Out:
#       marks  age sex   name
# ssn
# 5678     88   28   F  Sandy
# 1234     70   29   F   Jane
# 4567    100   31   F  Sally
# 3456     66   32   M   John

# %%
df1 = df.reindex(df.columns.sort_values(),axis=1)
df1
# Out:
#       age  marks   name sex
# ssn
# 5678   28     88  Sandy   F
# 1234   29     70   Jane   F
# 4567   31    100  Sally   F
# 3456   32     66   John   M

# %% [markdown]
# #**iloc**

# %%
# To retrieve an element purely on its index number, you use iloc.
a = pd.Series([100,200,300],index=['a','b','c'])
a.iloc[1]
# Out:
# 200

# %% [markdown]
# **iloc on DataFrame**
#
# For a DataFrame you can give both row and column index numbers to retrieve values.
#
# Now let us understand how to retrieve values in specific row(s) and column(s) using the loc function in a DataFrame:
#
# `dataFrame.iloc[<row selection>, <column selection>]` is used to select rows and columns by index number, in the order that they appear in the DataFrame. Row and column indexes start with 0 and span up to the length of the rows/columns - 1. Therefore, the last row index can be calculated by:
#
# `df.shape[0] -1`
#
# And to calculate the last column index, it would be
#
# `df.shape[1] -1`
#
# **iloc returns a scalar, Series or a DataFrame based on the results returned.** If only a single value is returned it would be one of the basic data types of NumPy. If a collection of one type is returned then a Series object. If two dimensional results are returned then it would be a DataFrame

# %%
row1=df1.iloc[0]
row1
# Out:
# age         28
# marks       88
# name     Sandy
# sex          F
# Name: 5678, dtype: object

# %%
type(row1)
# Out:
# pandas.core.series.Series

# %%
df1.iloc[0,1]
# Out:
# 88

# %%
df1.iloc[-1]
# Out:
# age        32
# marks      66
# name     John
# sex         M
# Name: 3456, dtype: object

# %%
df1.iloc[0:3]
# Out:
#       age  marks   name sex
# ssn
# 5678   28     88  Sandy   F
# 1234   29     70   Jane   F
# 4567   31    100  Sally   F

# %%
df1.iloc[0:3,0:2]
# Out:
#       age  marks
# ssn
# 5678   28     88
# 1234   29     70
# 4567   31    100

# %%
df = pd.DataFrame({
                'marks': [70, 66, 100, 88], 'age': [29, 32, 31, 28], \
                'sex': ['F', 'M', 'F', 'F'], 'name':['Jane', 'John', \
                'Sally', 'Sandy'], 'ssn':['1234', '3456', '4567', '5678']
                })

row_values = df.loc[0]
print(type(row_values))
# Out:
# <class 'pandas.core.series.Series'>

# %%
row_column = df.loc[[1, 3], 'name']
print(row_column)  # Series is returned
# Out:
# 1     John
# 3    Sandy
# Name: name, dtype: object

# %%
row_column = df.loc[1, ['name', 'age']]
print(row_column)  # Series is returned
# Out:
# name    John
# age       32
# Name: 1, dtype: object

# %%
row_column = df.loc[[1, 3], ['name','age']]
print(row_column)  # DataFrame is returned
# Out:
#     name  age
# 1   John   32
# 3  Sandy   28

# %%
df1
# Out:
#       age  marks   name sex
# ssn
# 5678   28     88  Sandy   F
# 1234   29     70   Jane   F
# 4567   31    100  Sally   F
# 3456   32     66   John   M

# %%
row_column = df1.loc[[1,3],'name']
print(row_column)  # Series is returned
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-af339286d7d6> in <module>()
# ----> 1 row_column = df1.loc[[1,3],'name']
#       2 print(row_column)  # Series is returned
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     860                     return section
#     861                 # This is an elided recursive call to iloc/loc
# --> 862                 return getattr(section, self.name)[new_key]
#     863
#     864         raise IndexingError("not applicable")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Int64Index([1, 3], dtype='int64', name='ssn')] are in the [index]"

# %%
row_column = df1.loc[1, ['name', 'age']]
print(row_column)  # Series is returned

# %%
row_column = df1.loc[df1.marks.idxmin()]
print(row_column)  # Series is returned
